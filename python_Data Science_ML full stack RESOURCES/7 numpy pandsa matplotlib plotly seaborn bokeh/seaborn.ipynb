# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")  # Purpose: To suppress warning messages during code execution.

# %%
#seaborn: statistical data visualization

# %%
# List of available datasets in seaborn library Purpose: To list all available built-in datasets in Seaborn.
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips') # Load the 'tips' dataset from the Seaborn library.

# %%
df # Display the first 5 rows of the dataset and last 5 rows .
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# The `sns.relplot` function from the Seaborn library is used to create a relational plot, which is useful for visualizing relationships between two variables. In the given code, `sns.relplot(x = 'total_bill', y = 'tip', data=df)` works as follows:
#
# 1. **x = 'total_bill'**: This specifies that the 'total_bill' column from the DataFrame `df` will be used for the x-axis of the plot.
#
# 2. **y = 'tip'**: This specifies that the 'tip' column from the DataFrame `df` will be used for the y-axis of the plot.
#
# 3. **data = df**: This indicates that the data for the plot comes from the DataFrame `df`.
#
# The resulting plot will display points where each point represents a data entry from `df`, showing the relationship between 'total_bill' and 'tip'. The x-axis will display the values of 'total_bill', and the y-axis will display the values of 'tip'.

# %%
#numerical data plotting
sns.relplot(x = 'total_bill', y = 'tip', data=df)  #relplot: relationship plot, x and y are the columns of the dataset
#the relationship between two variables, by default it gives scatterplot, kind='line'

# %% [markdown]
# The `sns.scatterplot` function from the Seaborn library creates a scatter plot, which is used to visualize the relationship between two continuous variables. The given code `sns.scatterplot(x = df.total_bill, y=df.tip, data=df, hue = 'smoker')` works as follows:
#
# 1. **x = df.total_bill**: This specifies that the `total_bill` column from the DataFrame `df` will be used for the x-axis of the plot.
#
# 2. **y = df.tip**: This specifies that the `tip` column from the DataFrame `df` will be used for the y-axis of the plot.
#
# 3. **data = df**: This indicates that the data for the plot comes from the DataFrame `df`.
#
# 4. **hue = 'smoker'**: This adds a third variable to the plot by color-coding the points according to the 'smoker' column in the DataFrame `df`. This means that points representing smokers and non-smokers will be colored differently, allowing you to see if there is any visible pattern or relationship based on whether a person is a smoker or not.
#
# The resulting plot will display points where each point represents a data entry from `df`, showing the relationship between `total_bill` and `tip`, with different colors representing the 'smoker' status.

# %%
sns.scatterplot(x = df.total_bill, y=df.tip, data=df, hue = 'smoker') # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points colored based on the smoker status.  #hue: color of the points based on the column 'smoker'
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# The `sns.relplot` function from Seaborn is a versatile function that can create different types of relational plots. By default, it creates a scatter plot, similar to `sns.scatterplot`, but it provides additional functionality for creating more complex visualizations.
#
# The given code `sns.relplot(x = 'total_bill', y = 'tip', data=df, hue = 'smoker')` works as follows:
#
# 1. **x = 'total_bill'**: Specifies that the 'total_bill' column from the DataFrame `df` will be used for the x-axis.
#
# 2. **y = 'tip'**: Specifies that the 'tip' column from the DataFrame `df` will be used for the y-axis.
#
# 3. **data = df**: Indicates that the data for the plot comes from the DataFrame `df`.
#
# 4. **hue = 'smoker'**: Adds a third variable to the plot by color-coding the points according to the 'smoker' column in the DataFrame `df`. This means that points representing smokers and non-smokers will be colored differently.
#
# The resulting plot will display points where each point represents a data entry from `df`, showing the relationship between 'total_bill' and 'tip'. The points will be colored based on the 'smoker' column, allowing you to see if there is any visible pattern or relationship based on whether a person is a smoker or not.
#
# In summary, `sns.relplot` with the given parameters creates a scatter plot similar to `sns.scatterplot`, with the added benefit of more flexibility and options for creating different types of relational plots.

# %%
#as the bill increase, the tip also increases
#highest tip was paid by a smoker
sns.relplot(x = 'total_bill', y = 'tip', data=df, hue = 'smoker') # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points colored based on the smoker status.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=df, hue = 'size') # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points colored based on the size of the group.

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=df, style = 'size',) # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points styled based on the size of the group.

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=df, style = 'smoker', hue = 'time') # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points styled based on the smoker status and colored based on the time of day.

# %%
#relplot to make a line plot>> we generated a data

time = np.arange(500) # Purpose: To generate an array of 500 time values.
value = np.random.randn(500).cumsum() # Purpose: To generate an array of 500 random values and calculate the cumulative sum of the values 
# The cumulative sum is useful in data analysis to understand the running total of a series of values. It can help identify trends over time..
df = pd.DataFrame({'time': time, 'value':value}) # Purpose: To create a DataFrame from the time and value arrays.

# %%
df
# Out:
#      time      value
# 0       0  -0.726843
# 1       1   0.710616
# 2       2  -0.176860
# 3       3  -0.418390
# 4       4  -1.136848
# ..    ...        ...
# 495   495 -26.838255
# 496   496 -25.710644
# 497   497 -24.879135
# 498   498 -25.207024
# 499   499 -24.893445
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y='value', kind = 'line', data = df, sort = True) # Purpose: To create a line plot showing the relationship between time and value. The data is sorted before plotting. #kind: type of plot, line plot is generated  #sort: sort the data before plotting

# %% [markdown]
# ```python
#
#
# # Create a line plot using sns.relplot
# sns.relplot(x='time', y='value', kind='line', data=df, sort=True)
# ```
#
# - `x='time'`: Specifies that the 'time' column from the DataFrame `df` will be used for the x-axis.
# - `y='value'`: Specifies that the 'value' column from the DataFrame `df` will be used for the y-axis.
# - `kind='line'`: Indicates that a line plot should be created.
# - `data=df`: Indicates that the data for the plot comes from the DataFrame `df`.
# - `sort=True`: Ensures that the data is sorted by the x-axis values before plotting.

# %% [markdown]
# ---
#
# **Code:**
#
# ```python
# # Load the fmri dataset
# df_fmri = sns.load_dataset('fmri')
# ```
#
# ---
#
# **Explanation:**
#
# - **Load the 'fmri' Dataset:**
#   ```python
#   df_fmri = sns.load_dataset('fmri')
#   ```
#   - `sns.load_dataset('fmri')` loads the 'fmri' dataset into a DataFrame named `df_fmri`.
#   - The 'fmri' dataset is one of the built-in datasets available in Seaborn.
#   - This dataset contains functional MRI (fMRI) data, which is often used for demonstration and educational purposes in data visualization and analysis.
#   - The dataset includes information about brain activity over time, typically captured during different experimental conditions.
#
# **Dataset Columns:**
# The 'fmri' dataset typically includes the following columns:
# - **subject**: Identifier for the subject in the experiment.
# - **timepoint**: The time point of the measurement.
# - **event**: The type of event or condition during the measurement.
# - **region**: The region of the brain where the measurement was taken.
# - **signal**: The measured brain activity signal.
#
#
#
# ---

# %%
fmri = sns.load_dataset('fmri') # Load the 'fmri' dataset from the Seaborn library.

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y='signal', kind = 'line', data=fmri) # Purpose: To create a line plot showing the relationship between timepoint and signal.

# %% [markdown]
# ci='sd': Stands for "confidence interval" and specifies that the error bands on the line plot should represent the standard deviation of the data at each time point. This helps in visualizing the variability of the signal measurements. The shaded area around the line will show the range within one standard deviation of the mean signal value at each time point.
#
# The resulting plot will display a line showing how the brain activity signal changes over time, with shaded bands representing the standard deviation of the signal values, providing insight into the variability of the measurements.

# %%
sns.relplot(x = 'timepoint', y='signal', kind = 'line', data=fmri, ci = 'sd') # Purpose: To create a line plot showing the relationship between timepoint and signal, with the standard deviation shown as a shaded region. #ci: confidence interval

# %%
sns.relplot(x = 'timepoint', y='signal',estimator = None, kind = 'line', data=fmri, ci = 'sd') # Purpose: To create a line plot showing the relationship between timepoint and signal, without any estimation of the central tendency.

# %% [markdown]
# ---
#
# **Code:**
#
# ```python
# sns.relplot(x='timepoint', y='signal', estimator=None, kind='line', data=fmri, ci='sd')
# ```
#
# ---
#
# **Explanation:**
#
# - **x='timepoint'**: Specifies that the 'timepoint' column from the DataFrame `fmri` will be used for the x-axis. This column represents the time points at which the measurements were taken.
#
# - **y='signal'**: Specifies that the 'signal' column from the DataFrame `fmri` will be used for the y-axis. This column represents the measured brain activity signal at each time point.
#
# - **estimator=None**: By setting `estimator` to `None`, it ensures that the plot will show all individual data points rather than aggregating them (e.g., taking the mean). This is useful for visualizing the raw data.
#
# - **kind='line'**: Indicates that a line plot should be created. A line plot is useful for visualizing changes in the signal over time.
#
#
# - **ci='sd'**: Stands for "confidence interval" and specifies that the error bands on the line plot should represent the standard deviation of the data at each time point. This helps in visualizing the variability of the signal measurements. The shaded area around the line will show the range within one standard deviation of the mean signal value at each time point.
#
# The resulting plot will display a line showing how the brain activity signal changes over time, with shaded bands representing the standard deviation of the signal values, and all individual data points included due to `estimator=None`.

# %%
sns.relplot(x = 'timepoint', y='signal', kind = 'line', data=fmri, hue = 'event') # Purpose: To create a line plot showing the relationship between timepoint and signal, with lines colored based on the event. #hue: color of the lines based on the column 'event'

# %%
sns.relplot(x = 'timepoint', y='signal', kind = 'line', data=fmri, hue = 'event', style = 'region') # Purpose: To create a line plot showing the relationship between timepoint and signal, with lines colored based on the event and styled based on the region. #style: style of the lines based on the column 'region'

# %%
sns.relplot(x = 'timepoint', y='signal', kind = 'line', data=fmri, hue = 'event', style = 'region', markers = True, dashes=False) # Purpose: To create a line plot showing the relationship between timepoint and signal, with lines colored based on the event, styled based on the region, and markers shown on the lines. #markers: markers on the lines  #dashes: dashes on the lines

# %%
tips = sns.load_dataset('tips') # Load the 'tips' dataset from the Seaborn library. #tips dataset is loaded again

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ```python
# sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, col='time')
# ```
#
# ### Components of the Code:
#
# 1. **`sns.relplot`**: This is the function call to create a relational plot. `relplot` is a high-level interface for creating scatter plots and line plots.
#
# 2. **`x='total_bill'`**: This sets the `total_bill` column of the `tips` DataFrame as the x-axis variable.
#
# 3. **`y='tip'`**: This sets the `tip` column of the `tips` DataFrame as the y-axis variable.
#
# 4. **`hue='smoker'`**: This sets the `smoker` column of the `tips` DataFrame as the hue variable, meaning that points will be colored based on whether the person is a smoker or not. Different colors will represent different categories (e.g., smoker and non-smoker).
#
# 5. **`data=tips`**: This specifies the DataFrame to be used for the plot. In this case, it is the `tips` DataFrame, which is a built-in dataset in Seaborn that contains information about tips received by waiters in a restaurant.
#
# 6. **`col='time'`**: This sets the `time` column of the `tips` DataFrame as the column variable, meaning that separate plots will be created for different values of `time` (e.g., lunch and dinner).
#
# ### What the Plot Shows:
#
# - **X-axis (`total_bill`)**: The total bill amount for each observation.
# - **Y-axis (`tip`)**: The tip amount for each observation.
# - **Hue (`smoker`)**: The data points will be colored differently based on whether the person is a smoker or not. For instance, smokers might be represented by one color and non-smokers by another.
# - **Columns (`time`)**: The data will be split into separate plots based on the `time` variable, which typically represents lunch and dinner in the `tips` dataset.
#
# ### Visual Interpretation:
#
# - **Scatter Plot**: The main plot type here is a scatter plot, where each point represents an observation.
# - **Color Differentiation**: Points will be color-coded to indicate whether the person is a smoker.
# - **Facet Grid**: There will be separate plots (columns) for different times of day, allowing for comparison between lunch and dinner.

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data = tips, col = 'time') # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points colored based on the smoker status, and with separate plots for each time category. #col: separate plots for each category in the column 'time'

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data = tips, col = 'size') # Purpose: To create a scatter plot showing the relationship between total_bill and tip, with points colored based on the smoker status, and with separate plots for each size category. #col: separate plots for each category in the column 'size'

# %% [markdown]
# The `sns.relplot()` function is being used again, but this time the `col` parameter is set to `'size'` instead of `'time'`. Here's a detailed explanation of this updated code:
#
# ```python
# sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, col='size')
# ```
#
# ### Components of the Code:
#
#
# 4. **`hue='smoker'`**: Points will be colored based on the `smoker` column, differentiating between smokers and non-smokers.
#
#
# 6. **`col='size'`**: Sets the `size` column of the `tips` DataFrame as the column variable. Separate plots will be created for different values of `size`.
#
# ### What the Plot Shows:
#
# - **X-axis (`total_bill`)**: The total bill amount for each observation.
# - **Y-axis (`tip`)**: The tip amount for each observation.
# - **Hue (`smoker`)**: Points will be color-coded based on whether the person is a smoker.
# - **Columns (`size`)**: The data will be split into separate plots based on the `size` variable, which typically represents the size of the dining party.
#
# ### Visual Interpretation:
#
# - **Scatter Plot**: Each point represents an observation.
# - **Color Differentiation**: Points are color-coded to indicate smoker status.
# - **Facet Grid**: Separate plots will be created for different sizes of dining parties, allowing comparison across different party sizes.
#
#
#
# ### Expected Output:
#
# The output will be a series of scatter plots arranged in columns, where each column represents a different dining party size. Within each plot, points will be color-coded to show whether the diner was a smoker. This allows you to see how the relationship between `total_bill` and `tip` varies with party size and smoker status.

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips) # Purpose: To create a scatter plot showing the relationship between total_bill and tip. #scatterplot is generated
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# The `sns.scatterplot()` function in Seaborn is used to create a scatter plot, which shows the relationship between two variables by plotting individual data points. Here's a detailed explanation of the given code:
#
# ```python
# sns.scatterplot(x='total_bill', y='tip', data=tips)
# ```
#
# ### Components of the Code:
#
# 1. **`sns.scatterplot`**: This is the function call to create a scatter plot.
#
# 2. **`x='total_bill'`**: Sets the `total_bill` column of the `tips` DataFrame as the x-axis variable.
#
# 3. **`y='tip'`**: Sets the `tip` column of the `tips` DataFrame as the y-axis variable.
#
# 4. **`data=tips`**: Specifies the DataFrame to be used for the plot. In this case, it is the `tips` DataFrame, which contains information about tips received by waiters in a restaurant.
#
# ### What the Plot Shows:
#
# - **X-axis (`total_bill`)**: The total bill amount for each observation.
# - **Y-axis (`tip`)**: The tip amount for each observation.
# - **Data Points**: Each point on the scatter plot represents a single observation from the dataset.
#
# ### Visual Interpretation:
#
# - **Scatter Plot**: This type of plot displays individual data points, allowing you to see the distribution and relationship between `total_bill` and `tip`.
# - **Trend**: By looking at the scatter plot, you can visually identify patterns, trends, and potential correlations between the two variables.
#
#
#
#
#
# ### Expected Output:
#
# The output will be a scatter plot with `total_bill` on the x-axis and `tip` on the y-axis. Each point represents an observation in the dataset, showing how the tip amount varies with the total bill amount.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# The `sns.catplot()` function in Seaborn is used to create categorical plots, which are useful for visualizing data that involves categorical variables. Here's a detailed explanation of the given code:
#
# ```python
# sns.catplot(x='day', y='total_bill', data=tips)
# ```
#
# ### Components of the Code:
#
# 1. **`sns.catplot`**: This is the function call to create a categorical plot. `catplot` is a high-level interface for drawing categorical plots.
#
# 2. **`x='day'`**: Sets the `day` column of the `tips` DataFrame as the x-axis variable. This column typically contains the days of the week (e.g., Thur, Fri, Sat, Sun).
#
# 3. **`y='total_bill'`**: Sets the `total_bill` column of the `tips` DataFrame as the y-axis variable.
#
# 4. **`data=tips`**: Specifies the DataFrame to be used for the plot. In this case, it is the `tips` DataFrame, which contains information about tips received by waiters in a restaurant.
#
# ### What the Plot Shows:
#
# - **X-axis (`day`)**: The days of the week.
# - **Y-axis (`total_bill`)**: The total bill amount for each observation.
# - **Categorical Plot**: By default, `catplot` will create a strip plot or a box plot, depending on the type of the data and Seaborn's default settings.
#
#
#
# ### Expected Output:
#
# The output will be a categorical plot showing the distribution of `total_bill` amounts for each day of the week. Each point represents an observation in the dataset.
#
# ### Customization and Plot Types:
#
# You can customize the type of plot by specifying the `kind` parameter in `catplot`. Common types include:
#
# 1. **Box Plot**:
#    ```python
#    sns.catplot(x='day', y='total_bill', kind='box', data=tips)
#    ```
#
# 2. **Violin Plot**:
#    ```python
#    sns.catplot(x='day', y='total_bill', kind='violin', data=tips)
#    ```
#
# 3. **Strip Plot**:
#    ```python
#    sns.catplot(x='day', y='total_bill', kind='strip', data=tips)
#    ```
#
# 4. **Swarm Plot**:
#    ```python
#    sns.catplot(x='day', y='total_bill', kind='swarm', data=tips)
#    ```
#
# ### Example with Box Plot:
#
# To create a box plot, which provides a more detailed view of the distribution, you can use the following code:
#
# ```python
# sns.catplot(x='day', y='total_bill', kind='box', data=tips)
# ```
#
# This will display a box plot for `total_bill` amounts for each day, showing the median, quartiles, and potential outliers.
#
# ### Conclusion:
#
# The `sns.catplot()` function is versatile and can be used to create various types of categorical plots to visualize the relationship between a categorical variable (`day`) and a numerical variable (`total_bill`). You can customize the plot type and appearance to suit your specific data visualization needs.

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips) # Purpose: To create a categorical plot showing the relationship between day and total_bill. #catplot: categorical plot

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm') # Purpose: To create a categorical plot showing the relationship between day and total_bill, with points distributed along the categorical axis. #kind: type of plot, swarm plot is generated

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'box') # Purpose: To create a categorical plot showing the relationship between day and total_bill, with box plots for each category. #kind: type of plot, box plot is generated

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin') # Purpose: To create a categorical plot showing the relationship between day and total_bill, with violin plots for each category. #kind: type of plot, violin plot is generated

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'boxen') # Purpose: To create a categorical plot showing the relationship between day and total_bill, with boxen plots for each category. #kind: type of plot, boxen plot is generated

# %% [markdown]
# The `sns.barplot()` function in Seaborn is used to create bar plots, which show the relationship between a categorical variable and a numerical variable by displaying the mean (or other statistical measures) of the numerical variable for each category. Here's a detailed explanation of the given code:
#
# ```python
# sns.barplot(x='day', y='total_bill', data=tips)
# ```
#
# ### Components of the Code:
#
# 1. **`sns.barplot`**: This is the function call to create a bar plot.
#
# 2. **`x='day'`**: Sets the `day` column of the `tips` DataFrame as the x-axis variable. This column typically contains the days of the week (e.g., Thur, Fri, Sat, Sun).
#
# 3. **`y='total_bill'`**: Sets the `total_bill` column of the `tips` DataFrame as the y-axis variable.
#
# 4. **`data=tips`**: Specifies the DataFrame to be used for the plot. In this case, it is the `tips` DataFrame, which contains information about tips received by waiters in a restaurant.
#
# ### What the Plot Shows:
#
# - **X-axis (`day`)**: The days of the week.
# - **Y-axis (`total_bill`)**: The average total bill amount for each day of the week.
# - **Bars**: Each bar represents the mean `total_bill` amount for a specific day, with error bars showing the confidence interval.
#
# ### Visual Interpretation:
#
# - **Bar Plot**: This type of plot displays the mean value of the numerical variable (`total_bill`) for each category (`day`).
# - **Error Bars**: The vertical lines on top of each bar represent the confidence interval, which provides an estimate of the variability around the mean.
#
#
#
#
# ### Expected Output:
#
# The output will be a bar plot showing the mean `total_bill` amounts for each day of the week, with error bars indicating the confidence intervals.
#
# ### Customization:
#
# You can further customize the bar plot by adding additional parameters:
#
# 1. **Change the Estimator**:
#    By default, `sns.barplot()` uses the mean as the estimator. You can change this to another function, such as the median:
#    ```python
#    sns.barplot(x='day', y='total_bill', estimator=np.median, data=tips)
#    ```
#
# 2. **Add Hue**:
#    You can add a `hue` parameter to differentiate categories within each day:
#    ```python
#    sns.barplot(x='day', y='total_bill', hue='sex', data=tips)
#    ```
#
# 3. **Change Colors**:
#    You can customize the color palette of the bars:
#    ```python
#    sns.barplot(x='day', y='total_bill', data=tips, palette='Blues_d')
#    ```
#
# ### Example with Hue:
#
# To create a bar plot that differentiates between male and female customers, you can use the following code:
#
# ```python
# sns.barplot(x='day', y='total_bill', hue='sex', data=tips)
# ```
#
# This will display separate bars for male and female customers for each day of the week, providing a more detailed comparison.
#
# ### Conclusion:
#
# The `sns.barplot()` function is a powerful tool for visualizing the relationship between a categorical variable and a numerical variable. It provides a clear and concise way to compare the mean (or other statistical measures) of the numerical variable across different categories, with the option to customize the plot in various ways to suit your data visualization needs.

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips) # Purpose: To create a bar plot showing the relationship between day and total_bill. #barplot is generated
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# The `sns.jointplot()` function in Seaborn is used to create a joint plot, which displays a bivariate scatter plot along with the univariate distribution of each variable on separate axes. This helps to visualize the relationship between two variables and their individual distributions. Here's a detailed explanation of the given code:
#
# ```python
# sns.jointplot(x=tips.total_bill, y=tips.tip)
# ```
#
# ### Components of the Code:
#
# 1. **`sns.jointplot`**: This is the function call to create a joint plot.
#
# 2. **`x=tips.total_bill`**: Specifies the `total_bill` column of the `tips` DataFrame as the x-axis variable.
#
# 3. **`y=tips.tip`**: Specifies the `tip` column of the `tips` DataFrame as the y-axis variable.
#
# ### What the Plot Shows:
#
# - **X-axis (`total_bill`)**: The total bill amount for each observation.
# - **Y-axis (`tip`)**: The tip amount for each observation.
# - **Bivariate Scatter Plot**: The central plot shows the relationship between `total_bill` and `tip` with individual data points.
# - **Marginal Histograms**: The plots on the top and right sides show the distributions of `total_bill` and `tip`, respectively.
#
# ### Visual Interpretation:
#
# - **Joint Plot**: This type of plot combines a scatter plot with marginal histograms to give a comprehensive view of the data.
# - **Scatter Plot**: The main plot shows how `total_bill` and `tip` are related.
# - **Histograms**: The histograms show the frequency distribution of `total_bill` and `tip`.
#
#
# ### Expected Output:
#
# The output will be a joint plot with a scatter plot in the center, showing the relationship between `total_bill` and `tip`, and marginal histograms on the top and right sides, showing the distributions of `total_bill` and `tip` respectively.
#
# ### Customization:
#
# You can further customize the joint plot by adding additional parameters:
#
# 1. **Change the Kind of Plot**:
#    You can change the kind of the central plot to a regression plot, hexbin plot, or kernel density estimate (KDE) plot:
#    ```python
#    sns.jointplot(x=tips.total_bill, y=tips.tip, kind='reg')  # Regression plot
#    sns.jointplot(x=tips.total_bill, y=tips.tip, kind='hex')  # Hexbin plot
#    sns.jointplot(x=tips.total_bill, y=tips.tip, kind='kde')  # KDE plot
#    ```
#
# 2. **Add Hue**:
#    You can add a `hue` parameter to differentiate categories within the data:
#    ```python
#    sns.jointplot(x='total_bill', y='tip', hue='smoker', data=tips)
#    ```
#
# ### Example with Regression Plot:
#
# To create a joint plot with a regression line, you can use the following code:
#
# ```python
# sns.jointplot(x=tips.total_bill, y=tips.tip, kind='reg')
# ```
#
# This will display a joint plot with a scatter plot in the center and a regression line fitted to the data, along with marginal histograms.
#
# ### Conclusion:
#
# The `sns.jointplot()` function is a versatile tool for visualizing the relationship between two variables and their individual distributions. It provides a comprehensive view of the data, combining scatter plots with marginal histograms or other plot types, and can be customized to suit various data visualization needs.

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip)  # Purpose: To create a joint plot showing the relationship between total_bill and tip. #jointplot is generated
#raw a plot of two variables with bivariate and univariate graphs.

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'reg') # Purpose: To create a joint plot showing the relationship between total_bill and tip, with a regression line. #kind: type of plot, regression line is generated

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'hex') # Purpose: To create a joint plot showing the relationship between total_bill and tip, with hexagonal bins. #kind: type of plot, hexagonal bins are generated

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = "kde") #kernel density estimator, contour>>meterological data, density of the data

# %%
#pairplot >> it will plot all the pairwise relationship btw dataframes
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# The `sns.pairplot()` function in Seaborn is used to create a pair plot, which is a matrix of scatter plots showing the relationships between pairs of variables in a dataset. Along the diagonal, it typically shows the distribution of each variable using histograms or KDE plots. Here's a detailed explanation of the given code:
#
# ```python
# sns.pairplot(tips)
# ```
#
# ### Components of the Code:
#
# 1. **`sns.pairplot`**: This is the function call to create a pair plot.
#
# 2. **`tips`**: This specifies the DataFrame to be used for the plot. In this case, it is the `tips` DataFrame, which contains information about tips received by waiters in a restaurant.
#
# ### What the Plot Shows:
#
# - **Scatter Plots**: Off-diagonal plots show scatter plots of the pairwise relationships between variables.
# - **Histograms/Kernel Density Estimates (KDEs)**: Diagonal plots show the distribution of each variable. By default, histograms are used, but KDEs can be specified.
# - **Axes**: Each row and column represent a variable in the dataset.
#
# ### Visual Interpretation:
#
# - **Pair Plot Matrix**: The pair plot creates a grid of plots, where each cell represents a combination of two variables, showing their relationship.
# - **Diagonal Plots**: The diagonal shows univariate plots for each variable, providing insight into the distribution of individual variables.
# - **Off-diagonal Plots**: The off-diagonal plots provide insights into the relationships between pairs of variables.
#
#
# ### Expected Output:
#
# The output will be a grid of scatter plots for each pair of variables in the `tips` DataFrame, along with histograms along the diagonal.
#
# ### Customization:
#
# You can customize the pair plot by adding additional parameters:
#
# 1. **Hue**:
#    You can add a `hue` parameter to differentiate categories within the data:
#    ```python
#    sns.pairplot(tips, hue='smoker')
#    ```
#
# 2. **Kind**:
#    You can change the kind of plot used on the diagonal (e.g., KDE instead of histograms):
#    ```python
#    sns.pairplot(tips, diag_kind='kde')
#    ```
#
# 3. **Markers**:
#    You can specify different markers for different categories:
#    ```python
#    sns.pairplot(tips, hue='smoker', markers=["o", "s"])
#    ```
#
# 4. **Plot Size**:
#    You can adjust the size of the plots:
#    ```python
#    sns.pairplot(tips, height=2.5)
#    ```
#
# ### Example with Hue:
#
# To create a pair plot with different colors for smokers and non-smokers, you can use the following code:
#
# ```python
# sns.pairplot(tips, hue='smoker')
# ```
#
# This will display a pair plot with points colored based on whether the person is a smoker or not, allowing for a more detailed comparison between groups.
#
# ### Conclusion:
#
# The `sns.pairplot()` function is a powerful tool for visualizing relationships between pairs of variables in a dataset. It provides a comprehensive view of the data, combining scatter plots and distribution plots, and can be customized to suit various data visualization needs.

# %%
sns.pairplot(tips) # Purpose: To create a pair plot showing the pairwise relationships between numerical columns in the tips dataset. #pairplot is generated

# %%
sns.pairplot(tips, hue = 'smoker') # Purpose: To create a pair plot showing the pairwise relationships between numerical columns in the tips dataset, with points colored based on the smoker status. #hue: color of the points based on the column 'smoker'

# %%
sns.pairplot(tips, hue = 'smoker', palette = 'coolwarm') # Purpose: To create a pair plot showing the pairwise relationships between numerical columns in the tips dataset, with points colored based on the smoker status and using the 'coolwarm' color palette. #hue: color of the points based on the column 'smoker' #palette: color palette
# https://seaborn.pydata.org/generated/seaborn.color_palette.html
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
#boxplot

sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = "rainbow") # Purpose: To create a box plot showing the relationship between day and total_bill, with the 'rainbow' color palette. #boxplot is generated
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data = tips, palette = "rainbow", orient = 'h') # Purpose: To create a box plot showing the distribution of total_bill, with the 'rainbow' color palette and horizontal orientation. #orient: orientation of the box plot  #boxplot is generated
# Out:
# <Axes: >

# %%
tips = tips[['total_bill', 'tip', 'size']] # Purpose: To select only the 'total_bill', 'tip', and 'size' columns from the tips dataset. #new dataframe is created

# %%
tips.corr() # Purpose: To calculate the correlation between the 'total_bill', 'tip', and 'size' columns in the tips dataset. #correlation is calculated
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cmap = "coolwarm", annot = True) # Purpose: To create a heatmap showing the correlation between the 'total_bill', 'tip', and 'size' columns in the tips dataset. #cmap: color map #annot: annotation of the values on the heatmap
# Out:
# <Axes: >

# %%
df = sns.load_dataset("tips") # Load the 'tips' dataset from the Seaborn library. #tips dataset is loaded again

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = 'sex', data=df) # Purpose: To create a count plot showing the distribution of
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data=df) # Purpose: To create a linear regression plot showing the relationship between total_bill and tip. #lmplot is generated  #linear regression plot is generated

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data=df, height = 15, aspect = 1) # Purpose: To create a linear regression plot showing the relationship between total_bill and tip, with a height of 15 and an aspect ratio of 1. #lmplot is generated  #linear regression plot is generated
