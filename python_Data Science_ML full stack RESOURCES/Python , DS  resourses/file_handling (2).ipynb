# %%
import sys

# %%
sys.stdout = open("hello.txt","w")
print ("AAAAAAAAAAAAAAAAaa")  #instead of printing on console, it will print inside file hello.txt 
sys.stdout.close()

# %%
f= open(r"C:\Users\home\Desktop\Machine Learning\datasets\bank-names.txt",'r')
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\home\\Desktop\\Machine Learning\\datasets\\bank-names.txt' mode='r' encoding='cp1252'>

# %%
f= open(r"C:\Users\home\Desktop\Machine Learning\datasets\Superstore.xls")

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
f.writelines("NEW LINES")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-2-5518d73a4f18> in <module>
# ----> 1 f.writelines("NEW LINES")
#
# UnsupportedOperation: not writable

# %%
for l in f.readlines():
    print(l)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-14-b6cef137d886> in <module>
# ----> 1 for l in f.readlines():
#       2     print(l)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 1782: character maps to <undefined>

# %%
import struct

# %%
data = r"C:\Users\home\Desktop\a.jpg"
img = open(data,'rb')
img_read = img.read()

# %%
values = struct.unpack('>i4shf', data)bbbb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-775a4dfb060c> in <module>()
# ----> 1 values = struct.unpack('>i4shf', data)
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
data = r"C:\Users\home\Desktop\deep Learning\convolution_NN\bird.jpg"
data
# Out:
# 'C:\\Users\\home\\Desktop\\deep Learning\\convolution_NN\\bird.jpg'

# %%
img = mpimg.imread(data)
plt.imshow(img)

# %%
from PIL import Image

# %%
img2 = Image.open(data)

# %%
img2.show()

# %%
img2.format
# Out:
# 'JPEG'

# %%
img2.mode
# Out:
# 'RGB'

# %%
import os
def fn():       # 1.Get file names from directory
    file_list=os.listdir(r"C:\Users\home\Desktop\Machine Learning\datasets")
    for i in file_list:
        file_name = 'C:\\Users\\home\\Desktop\\Machine Learning\\datasets\\'+i 
        d=os.stat(file_name).st_size
        print (file_name,d)

 #2.To rename files
fn()
# Out:
# C:\Users\home\Desktop\Machine Learning\datasets\.RData 66431
# C:\Users\home\Desktop\Machine Learning\datasets\.Rhistory 10315
# C:\Users\home\Desktop\Machine Learning\datasets\ABSA.diabetes_india.csv 201253
# C:\Users\home\Desktop\Machine Learning\datasets\accidental-deaths-in-usa-monthly.csv 1217
# C:\Users\home\Desktop\Machine Learning\datasets\ads.csv 5781
# C:\Users\home\Desktop\Machine Learning\datasets\ads_hour.csv 40997
# C:\Users\home\Desktop\Machine Learning\datasets\adult.data.csv 3518607
# C:\Users\home\Desktop\Machine Learning\datasets\adult_test.csv 2368966
# C:\Users\home\Desktop\Machine Learning\datasets\adult_train.csv 4380698
# C:\Users\home\Desktop\Machine Learning\datasets\Advertising.csv 5469
# C:\Users\home\Desktop\Machine Learning\datasets\affairs.csv 286041
# C:\Users\home\Desktop\Machine Learning\datasets\AirPassengers.csv 1746
# C:\Users\home\Desktop\Machine Learning\datasets\animals.xlsx 9723
# ...

# %%
import shutil
shutil.copy('hello.txt', 'C:\\Users\\home\\Desktop\\target.txt')
# Out:
# 'C:\\Users\\home\\Desktop\\target.txt'

# %%
shutil.copytree('C:\\Users\\home\\Desktop\\Day 3','E:\\python\\DAY3')
# Out:
# 'E:\\python\\DAY3'

# %%
f = open("myfile.txt", "w")             #file  object created in write mode, in current folder 
print (dir(f))

print ("-------------------------------------------------------------------")
f.write("ZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ\n")
f.write("BBBBBBBBBBBBBBAAAAA\n")
f.write("END!!")
f.close()
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']
# -------------------------------------------------------------------

# %%
f = open("myfile.txt", "a")             #file  object created in write mode, in current folder 
print (dir(f))

print ("-------------------------------------------------------------------")
f.write("ZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ\n")
f.write("BBBBBBBBBBBBBBAAAAA\n")
f.write("END!!")
f.close()

# %%
f = open('target.txt', "w")
f.write("hello----World")
f.close()

f = open("target.txt")   #by default read mode
while True:
        str1 = f.readline()
        print ("position in loop = ", f.tell())
        if str1:
                print (str1)
        else:
                break
print ("----------------------------------------------")  #f is pointing at the end of file
f.seek(5)   #absolute positioning from beginning of a file 
print ("Current position = ", f.tell())   #5
print (f.read())    #" World\n"
f.close()
# Out:
# position in loop =  14
# hello----World
# position in loop =  14
# ----------------------------------------------
# Current position =  5
# ----World
