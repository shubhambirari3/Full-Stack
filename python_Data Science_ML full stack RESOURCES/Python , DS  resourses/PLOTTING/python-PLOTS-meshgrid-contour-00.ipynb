# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
xvalues = np.array([0, 1, 2, 3, 4]);
yvalues = np.array([0, 1, 2, 3, 4]);

# %%
xx, yy = np.meshgrid(xvalues, yvalues)

plt.plot(xx, yy, marker='.', color='k', linestyle='dashed', markersize = 12, linewidth = 5);

# %%
u    = np.linspace(-2, 2, 3)
v    = np.linspace(-1, 1, 5)
print (u)
print (v)
X, Y = np.meshgrid(u, v)
plt.plot(X, Y, marker='.', color='c', linestyle='none');

Z = X**2/25 + Y**2/4
# Out:
# [-2.  0.  2.]
# [-1.  -0.5  0.   0.5  1. ]

# %%
X
# Out:
# array([[-2.,  0.,  2.],
#        [-2.,  0.,  2.],
#        [-2.,  0.,  2.],
#        [-2.,  0.,  2.],
#        [-2.,  0.,  2.]])

# %%
Y
# Out:
# array([[-1. , -1. , -1. ],
#        [-0.5, -0.5, -0.5],
#        [ 0. ,  0. ,  0. ],
#        [ 0.5,  0.5,  0.5],
#        [ 1. ,  1. ,  1. ]])

# %%
Z
# Out:
# array([[0.41  , 0.25  , 0.41  ],
#        [0.2225, 0.0625, 0.2225],
#        [0.16  , 0.    , 0.16  ],
#        [0.2225, 0.0625, 0.2225],
#        [0.41  , 0.25  , 0.41  ]])

# %%
print('Z:\n', Z)
plt.set_cmap('Greens_r')
plt.pcolor(Z)
# Out:
# Z:
#  [[0.41   0.25   0.41  ]
#  [0.2225 0.0625 0.2225]
#  [0.16   0.     0.16  ]
#  [0.2225 0.0625 0.2225]
#  [0.41   0.25   0.41  ]]

# %% [markdown]
# #### Bivariate functions
#
# ![image.png](attachment:image.png)

# %%
 u = np.linspace(-2, 2, 65)
 v = np.linspace(-1, 1, 33)
 X,Y = np.meshgrid(u, v)
 Z = X**2/25 + Y**2/4
plt.pcolor(Z, cmap= 'autumn');
plt.colorbar()

# %%
plt.pcolor(X, Y, Z) # X, Y are 2D meshgrid
plt.colorbar()
plt.axis('tight')
# Out:
# (-2.0, 2.0, -1.0, 1.0)

# %%
# Plot using mesh grid

# %%
plt.contour(Z)
plt.contour(Z, 15)

# %%
plt.contour(X, Y, Z, 15) 
plt.colorbar()

# %%
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
z = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)

# %%
h = plt.contourf(x,y,z)
