# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\home\Desktop\Machine Learning\datasets\Advertising.csv")

# %%
df
# Out:
#       Month     TV  radio  newspaper  sales
# 0    Jan-00  230.1   37.8       69.2   22.1
# 1    Feb-00   44.5   39.3       45.1   10.4
# 2    Mar-00   17.2   45.9       69.3    9.3
# 3    Apr-00  151.5   41.3       58.5   18.5
# 4    May-00  180.8   10.8       58.4   12.9
# ..      ...    ...    ...        ...    ...
# 195  Apr-16   38.2    3.7       13.8    7.6
# 196  May-16   94.2    4.9        8.1    9.7
# 197  Jun-16  177.0    9.3        6.4   12.8
# 198  Jul-16  283.6   42.0       66.2   25.5
# 199  Aug-16  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
location="https://en.wikipedia.org/wiki/Periodic_table"

# %%
loc_html=pd.read_html(location)

# %%
loc_html
# Out:
# [                                                    0
#  0                             Part of a series on the
#  1                                      Periodic table
#  2   Periodic table forms 18-column 32-column Alter...
#  3   Periodic table history Dmitri Mendeleev predic...
#  4                                    Sets of elements
#  5   By periodic table structure Groups (1–18) 1 (a...
#  6   By metallic classification Metals alkali alkal...
#  7   By other characteristics Coinage metals Platin...
#  8                                            Elements
#  9   List of chemical elements by abundance (in hum...
#  10  Properties of elements Atomic weight Crystal s...
#  11  Data pages for elements Abundance Atomic radiu...
#  12                   Book  Category  Chemistry Portal
#  13                                                vte,
#         Group                     1                      2  \
#  0        NaN         Alkali metals  Alkaline earth metals
# ...

# %%
type(loc_html)
# Out:
# list

# %%
pd.DataFrame(loc_html)
# Out:
#                                                     0
# 0                                                 ...
# 1          Group                     1            ...
# 2                0                     1          ...
# 3                 Group →                         ...
# 4                0                     1          ...
# 5                            0                    ...
# 6             0          1          2        3    ...
# 7          Group →                                ...
# 8                0                     1          ...
# 9                0        1        2        3     ...
# 10                             0
# 0  La and Ac below Y
# 11                             0
# 0  Lu and Lr below Y
# 12                               0
# 0  Markers below Y
# 13            0          1          2   3        4...
# 14             0           1          2   3       ...
# 15      0                     1
# 0 NaN  Book: Perio...
# ...
