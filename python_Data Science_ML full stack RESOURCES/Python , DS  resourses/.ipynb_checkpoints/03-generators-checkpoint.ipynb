# %% [markdown]
# ## What are generators..?
#
#     Generators functions that return traversable objects
#     Produce items one at a time and only when required.

# %% [markdown]
# ## Advantages of generators:
#     it implement __iter__() , __next__(), stop() automatically
#     helps to save memory
#     used to produce infinite items
#     used to pipeline number of operatos.

# %% [markdown]
# ## Generators:
#     Mark use of ##yeild## keyword
#     run when next methos is called
#     produce item one at a time and whenever it is required.

# %%
# city names generator
### yeild is used as return
def city_generator():
            
    yield("Bangalore")
            
    yield("Kolkata")
    yield("Delhi")
    yield("Mumbai")

# %%
city = city_generator()
city
# Out:
# <generator object city_generator at 0x0000014D79F74930>

# %%
next(city)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-9-f885c2feb4a5> in <module>()
# ----> 1 next(city)
#
# StopIteration:

# %%
next(city)
# Out:
# 'Kolkata'

# %%
next(city)
# Out:
# 'Delhi'

# %%
next(city)
# Out:
# 'Mumbai'

# %%
# fibonacci number series
def fibonacci(max):
    a, b = 0, 1
    while a < max:
        yield a
        a, b = b, a+b

# %%
fibonacci(9)
# Out:
# <generator object fibonacci at 0x0000014D7A02F390>

# %%
fib = fibonacci(100)

# %%
next(fib)
# Out:
# 2

# %%
#for fib in '13':
for fib in fibonacci(9):
    print(fib)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
# once we have "consumed" the generator, we can't use it anymore 
# because generators in Python can't be rewound.

# %%
def squares(n=10):
    print('Generating squares from 1 to {0}'.format(n ** 2))
    for i in range(0, n +1):
        yield i ** 2

# %%
sq = squares()

# %%
next(sq)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-59-498d28888231> in <module>()
# ----> 1 next(sq)
#
# StopIteration:

# %%
for sq in squares():
    print(sq)
# Out:
# Generating squares from 1 to 100
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
# using generator comprehension
gen = (x ** 2 for x in range(10))

# %%
next(gen)
# Out:
# 64

# %%
for i in gen:
    print(i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

def s(flip=2):
    x=np.linspace(0,14,100)
    for i in range(1,5):
            plt.plot(x,np.sin(x+i*.5)*(7-i)*flip)
            
sb.set()
s()
plt.show()

# %%
import seaborn as sb
import numpy as np
from matplotlib import pyplot as plt

def s(flip=2):
    x=np.linspace(0,14,100)
    for i in range(1,10):
            yield(plt.plot(x,np.sin(x+i*.5)*(7-i)*flip))
# Out:
# [<matplotlib.lines.Line2D object at 0x00000211E726E940>]
# [<matplotlib.lines.Line2D object at 0x00000211E616A518>]

# %%
sb.set()
generator=s()
print(next(generator))
print(next(generator))
print(next(generator))
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x00000211E7320E10>]
# [<matplotlib.lines.Line2D object at 0x00000211E72EE128>]
# [<matplotlib.lines.Line2D object at 0x00000211E7320F98>]
