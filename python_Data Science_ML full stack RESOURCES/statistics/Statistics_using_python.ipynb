# %% [markdown]
# ## Central tendancy

# %%
a=[1,2,3,3,2,1,3,4,5,3,4,5]

# %%
import numpy as np

# %%
a_arr = np.array(a)

# %%
a_arr
# Out:
# array([1, 2, 3, 3, 2, 1, 3, 4, 5, 3, 4, 5])

# %%
a_arr.mean()
# Out:
# 3.0

# %%
import statistics as stat

# %%
stat.median(a_arr)
# Out:
# 3.0

# %%
stat.mode(a_arr)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list(range(0,6))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import numpy as np

# %%
np.arange(0,6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a_arr
# Out:
# array([1, 2, 3, 3, 2, 1, 3, 4, 5, 3, 4, 5])

# %%
a_arr.mean()
# Out:
# 3.0

# %%
a_arr.var()
# Out:
# 1.6666666666666667

# %%
a_arr.std()
# Out:
# 1.2909944487358056
