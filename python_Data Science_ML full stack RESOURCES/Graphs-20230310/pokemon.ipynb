# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E:\Python\Machine Learning\datasets\Pokemon.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
obj=df.groupby("Type 1")

# %%
avg_df = obj.mean()

# %%
avg_df
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
import matplotlib.pyplot as plt

# %%
avg_df.index
# Out:
# Index(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'],
#       dtype='object', name='Type 1')

# %%
list(zip(avg_df.index, avg_df['Attack'],avg_df['Speed']))
# Out:
# [('Bug', 70.97101449275362, 61.68115942028985),
#  ('Dark', 88.38709677419355, 76.16129032258064),
#  ('Dragon', 112.125, 83.03125),
#  ('Electric', 69.0909090909091, 84.5),
#  ('Fairy', 61.529411764705884, 48.588235294117645),
#  ('Fighting', 96.77777777777777, 66.07407407407408),
#  ('Fire', 84.76923076923077, 74.4423076923077),
#  ('Flying', 78.75, 102.5),
#  ('Ghost', 73.78125, 64.34375),
#  ('Grass', 73.21428571428571, 61.92857142857143),
#  ('Ground', 95.75, 63.90625),
#  ('Ice', 72.75, 63.458333333333336),
#  ('Normal', 73.46938775510205, 71.55102040816327),
#  ('Poison', 74.67857142857143, 63.57142857142857),
#  ('Psychic', 71.45614035087719, 81.49122807017544),
#  ('Rock', 92.86363636363636, 55.90909090909091),
#  ('Steel', 92.70370370370371, 55.25925925925926),
#  ('Water', 74.15178571428571, 65.96428571428571)]

# %%
plt.figure(figsize=(16, 10))
plt.scatter(avg_df['Attack'],avg_df['Speed'])

for label,a,s in zip(avg_df.index, avg_df['Attack'],avg_df['Speed']):
    plt.annotate(label,
                 xy=(a, s), # put the label with its point
                 xytext=(4, 5),                  # but slightly offset
                 textcoords='offset points')
plt.title("type 1 average attack against avg speed")
plt.xlabel("avg attack")
plt.ylabel("avg Speed")
plt.show()

# %%
type1_df=pd.DataFrame(columns = ["T1_cnt", 'T2_cnt'],index=avg_df.index)

# %%
type1_df.index
# Out:
# Index(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'],
#       dtype='object', name='Type 1')

# %%
type1_df
# Out:
#          T1_cnt T2_cnt
# Type 1
# Bug         NaN    NaN
# Dark        NaN    NaN
# Dragon      NaN    NaN
# Electric    NaN    NaN
# Fairy       NaN    NaN
# Fighting    NaN    NaN
# Fire        NaN    NaN
# Flying      NaN    NaN
# Ghost       NaN    NaN
# Grass       NaN    NaN
# Ground      NaN    NaN
# Ice         NaN    NaN
# Normal      NaN    NaN
# Poison      NaN    NaN
# Psychic     NaN    NaN
# Rock        NaN    NaN
# Steel       NaN    NaN
# Water       NaN    NaN

# %%
avg_df.index
# Out:
# Index(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'],
#       dtype='object', name='Type 1')

# %%
df['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Water       14
# Ghost       14
# Ice         14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
plt.figure(figsize=(16, 10))
plt.stackplot(avg_df.index,df['Type 2'].value_counts(),df['Type 1'].value_counts() )

# %%
type1_df
# Out:
#          T1_cnt T2_cnt
# Type 1
# Bug          10      5
# Dark         11      6
# Dragon       12      7
# Electric     13      8
# Fairy        14      9
# Fighting     15     10
# Fire         16     11
# Flying       17     12
# Ghost        18     13
# Grass        19     14
# Ground       20     15
# Ice          21     16
# Normal       22     17
# Poison       23     18
# Psychic      24     19
# Rock         25     20
# Steel        26     21
# Water        27     22

# %%
a=10
b=5
tot=0
for i in type1_df.iterrows():
    #print("T1cnt = ", i[1]['T1_cnt'])
    i[1]['T1_cnt']=a+tot
    #print("T2cnt = ", i[1]['T2_cnt'])
    i[1]['T2_cnt'] = b+tot
    tot=tot+1
# Out:
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan
# T1cnt =  nan
# T2cnt =  nan

# %%
t1_vc = df['Type 1'].value_counts()

# %%
for i in t1_vc:
    print(i)
# Out:
# 112
# 98
# 70
# 69
# 57
# 52
# 44
# 44
# 32
# 32
# 32
# 31
# 28
# 27
# 27
# 24
# 17
# 4

# %%
for i in type1_df.iteritems():
    print(i)
# Out:
# ('T1_cnt', Type 1
# Bug         NaN
# Dark        NaN
# Dragon      NaN
# Electric    NaN
# Fairy       NaN
# Fighting    NaN
# Fire        NaN
# Flying      NaN
# Ghost       NaN
# Grass       NaN
# Ground      NaN
# Ice         NaN
# Normal      NaN
# Poison      NaN
# Psychic     NaN
# Rock        NaN
# Steel       NaN
# Water       NaN
# Name: T1_cnt, dtype: object)
# ('T2_cnt', Type 1
# Bug         NaN
# Dark        NaN
# Dragon      NaN
# Electric    NaN
# Fairy       NaN
# Fighting    NaN
# Fire        NaN
# Flying      NaN
# Ghost       NaN
# Grass       NaN
# Ground      NaN
# Ice         NaN
# Normal      NaN
# Poison      NaN
# Psychic     NaN
# Rock        NaN
# Steel       NaN
# Water       NaN
# Name: T2_cnt, dtype: object)
