# %%
# !pip install mysql-connector-python

# %%
# !pip install mysql-connector-python

# %%
 import mysql.connector as vick

# %%
#myac = vick.connect(host = 'localhost',user = 'root', passwd = '@57djwa2fh4')
#password is wrong

# %%
myac

# %%
cursor = myac.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('sys',)]

# %%
cursor = myac.cursor()

# %%
cursor.execute('create a databases shubh')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'a databases shubh' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/2629481894.py in <module>
# ----> 1 cursor.execute('create a databases shubh')
#
# ...

# %%
cursor.execute("jhsdbajhv")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'jhsdbajhv' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/3863957960.py in <module>
# ----> 1 cursor.execute("jhsdbajhv")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
# ...

# %%
create table testshubh.ineuron()
# Out:
#   File "C:\Users\shubh\AppData\Local\Temp/ipykernel_8964/2657090316.py", line 1
#     create table testshubh.ineuron
#            ^
# SyntaxError: invalid syntax

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost',user = 'root' ,passwd = "@57djwa2fh4" )
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     235         try:
# --> 236             self._cmysql.connect(**cnx_kwargs)
#     237             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (10061)
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18364/109780301.py in <module>
# ----> 1 mydb = conn.connect(host = 'localhost',user = 'root' ,passwd = "@57djwa2fh4" )
#
# ~\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     270
#     271     if HAVE_CEXT and not use_pure:
# ...

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testshubh123',),
#  ('testsudhineuron',)]

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database testshubh1234")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7648/2684620936.py in <module>
# ----> 1 cursor.execute("create database testshubh1234")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     241         if not self._cnx or self._cnx.is_closed():
#     242             raise errors.ProgrammingError("Cursor is not connected", 2055)
# --> 243         self._cnx.handle_unread_result()
#     244
#     245         stmt = ''
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     792             self.consume_results()
#     793         elif unread_result:
# --> 794             raise errors.InternalError("Unread result found")
#     795
#     796     def reset_session(self, user_variables=None, session_variables=None):
#
# ...

# %%
cursor.execute('create table testshubh123.ineuron(studentid INT(10) ,firstname VARCHAR(30)  ,lastname VARCHAR(30) ,regid INT(10) ,classname VARCHAR(30))')

# %%
cursor.execute("show databases")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7648/4214473682.py in <module>
# ----> 1 cursor.execute("show databases")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     241         if not self._cnx or self._cnx.is_closed():
#     242             raise errors.ProgrammingError("Cursor is not connected", 2055)
# --> 243         self._cnx.handle_unread_result()
#     244
#     245         stmt = ''
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     792             self.consume_results()
#     793         elif unread_result:
# --> 794             raise errors.InternalError("Unread result found")
#     795
#     796     def reset_session(self, user_variables=None, session_variables=None):
#
# ...

# %%
cursor.execute('use testshubh123 ')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('ineuron',)]

# %%
cursor.execute('insert into testshubh123.ineuron values(1123),"shubh"','vicky',"shfshj")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/2798230468.py in <module>
# ----> 1 cursor.execute('insert into testshubh123.ineuron values(1123),"shubh"','vicky',"shfshj")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     255
#     256         if params:
# --> 257             prepared = self._cnx.prepare_for_mysql(params)
#     258             if isinstance(prepared, dict):
#     259                 for key, value in prepared.items():
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in prepare_for_mysql(self, params)
#     684                     result[key] = self._cmysql.convert_to_mysql(value)[0]
#     685         else:
# --> 686             raise errors.ProgrammingError(
# ...

# %%
cursor.execute('use  testsudhineuron')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in get_rows(self, count, binary, columns, raw, prep_stmt)
#     364                     break
# --> 365                 row = fetch_row()
#     366             if not row:
#
# MySQLInterfaceError: Commands out of sync; you can't run this command now
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/589454993.py in <module>
# ----> 1 cursor.fetchall()
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in fetchall(self)
#     508             return []
#     509
# --> 510         rows = self._cnx.get_rows()
#     511         if self._nextrow and self._nextrow[0]:
# ...

# %%
cursor.execute('insert into testshubh123.ineuron values(423423 , "sudh" , "kumar" , 2344323 , "FSDS")')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/3167869456.py in <module>
# ----> 1 cursor.execute('insert into testshubh123.ineuron values(423423 , "sudh" , "kumar" , 2344323 , "FSDS")')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     241         if not self._cnx or self._cnx.is_closed():
#     242             raise errors.ProgrammingError("Cursor is not connected", 2055)
# --> 243         self._cnx.handle_unread_result()
#     244
#     245         stmt = ''
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     792             self.consume_results()
#     793         elif unread_result:
# --> 794             raise errors.InternalError("Unread result found")
#     795
# ...

# %%
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/4062422964.py in <module>
# ----> 1 mydb.commit()
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in commit(self)
#     411         """Commit current transaction"""
#     412         if self._cmysql:
# --> 413             self._cmysql.commit()
#     414
#     415     def rollback(self):
#
# MySQLInterfaceError: Commands out of sync; you can't run this command now

# %%
cursor.execute('select * from testshubh123.ineuron')

# %% [raw]
# cursor.fetchall()

# %%
cursor.execute("select * from  testsudhineuron.ineuron")

# %%
cursor.fetchall()
# Out:
# [(423423, 'sudh', 'kumar', 2344323, 'FSDS')]

# %%
cursor.execute('insert into testsudhineuron.ineuron values(564576 , "suhghfdh" , "kumar" , 2344323 , "FSDS")')

# %%
cursor.execute('create table testshubh123.glassdata3(col1 INT(10) ,col2 float(10,5),col3 float(10,5) ,col4 float(10,5) , col5 float(10,5),col6 float(10,5) ,clo7 float(10,5) , col8 float(10,5) , col9 float(10,5) , col10 float(10,5) , col11 INT(10)) ')

# %%
cursor.execute('use testshubh123')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('glassdata3',), ('ineuron',)]

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 7293-F0DC
#
#  Directory of C:\Users\shubh
#
# 06/02/2022  12:17 PM    <DIR>          .
# 29/10/2021  02:41 PM    <DIR>          ..
# 05/02/2022  05:07 PM    <DIR>          .conda
# 04/12/2021  10:20 AM                25 .condarc
# 04/12/2021  10:20 AM    <DIR>          .continuum
# 06/02/2022  10:38 AM    <DIR>          .ipynb_checkpoints
# 04/12/2021  10:54 AM    <DIR>          .ipython
# 20/12/2021  07:48 PM    <DIR>          .jupyter
# 07/11/2021  11:49 PM    <DIR>          .Ld2VirtualBox
# 22/01/2022  10:17 AM    <DIR>          .matplotlib
# 22/01/2022  10:17 AM    <DIR>          .spyder-py3
# 22/01/2022  10:37 AM    <DIR>          __pycache__
# 31/10/2021  12:32 PM             6,893 -1.14-windows.xml
# 03/12/2021  12:51 PM    <DIR>          103419079040931888859
# 28/10/2021  02:53 PM    <DIR>          3D Objects
# 23/12/2021  09:54 PM           102,264 abcd.ipynb
# 22/12/2021  08:50 PM    <DIR>          anaconda3
# ...

# %%
file  = open("glass.data" , 'r')

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
with open ('glass.data ', 'r') as f
# Out:
#   File "C:\Users\shubh\AppData\Local\Temp/ipykernel_19040/1866942275.py", line 1
#     with open ('glass.data ', 'r') as f
#                                        ^
# SyntaxError: invalid syntax

# %%
import csv
with open ("glass.data", 'r') as f :
    csv.reader(f ,delimiter = '\n'):
        print
# Out:
#   File "C:\Users\shubh\AppData\Local\Temp/ipykernel_19040/3181390759.py", line 1
#     with open ("glass.data", 'r') as f :
#                                         ^
# IndentationError: expected an indented block

# %%
import csv
with open('glass.data' , 'r') as f :
    glass_data = csv.reader(f , delimiter = '\n')
    for i in glass_data:
        print(i[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
cursor.execute('create table testsudhineuron.glassdata(col1 INT(10) ,col2 float(10,5),col3 float(10,5) ,col4 float(10,5) , col5 float(10,5),col6 float(10,5) ,clo7 float(10,5) , col8 float(10,5) , col9 float(10,5) , col10 float(10,5) , col11 INT(10)) ')

# %%
cursor.execute('insert into testsudhineuron.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)')

# %%
mydb.commit()

# %%
cursor.execute('select * from testsudhineuron.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
with open('glass.data','r') as f:
    glass_data=csv.reader(f,delimiter='\n')
    for i in glass_data:
        print(type(i[0]))
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute('insert into testsudhineuron.glassdata values({values})'.format(values = ((i[0]))))
# Out:
# <class 'str'>
# insert into glassdata values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# <class 'str'>
# insert into glassdata values (7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1)
# <class 'str'>
# ...

# %%
mydb.commit()

# %%
import pandas as pd

# %%
pd.read_sql("select * from testsudhineuron.glassdata" , mydb)
# Out:
#      col1     col2   col3  col4  col5   col6  clo7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 2       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 3       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# 4       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 638   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# 639   211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.0      7
# 640   212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.0      7
# 641   213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.0      7
# 642   214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.0      7
#
# [643 rows x 11 columns]

# %%
pd.read_sql("show databases" , mydb)
# Out:
#               Database
# 0       carbonnanotube
# 1            glassdata
# 2           glassdata1
# 3          glassdata11
# 4         glassdata123
# 5   information_schema
# 6                mysql
# 7   performance_schema
# 8               sakila
# 9              student
# 10            student1
# 11           student12
# 12          student234
# 13          student546
# 14                sudh
# 15             sudh123
# 16      sudhanshu12345
# 17                 sys
# 18          test234344
# 19         testineuron
# 20            testsudh
# 21     testsudhineuron
# 22               world

# %%
 cursor.execute('create table testshubh123.glassdata(col1 INT(10), col2 float (10,5),clo3 float(10,4),clo4 float(23,2),clo5 float(10,5),clo6 float(10,5),col7 float(10,5),clo8 float(4,4),clo9 float(10,5),clo10 float(10,5),clo 11 float(10,5))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '11 float(10,5))' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/1893200061.py in <module>
# ...

# %%
###### new practice notebook

# %%
import mysql.connector as conn

# %%
shu = conn.connect(host = 'localhost', user= 'root' , passwd = "shubham098" )

# %%
shu

# %%
cursor = shu.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('tesstsql',),
#  ('testsql',)]

# %%
cursor = shu.cursor()

# %%
#cursor.execute("create database tesstsql2")

# %%
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('tesstsql',),
#  ('tesstsql2',),
#  ('testsql',)]

# %%
cursor.execute("create table testsql.tablesql(studentid INT(10) , firstname VARCHAR(30) , regid INT(10) , classname VARCHAR(30))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'tablesql' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9992/3822921306.py in <module>
# ----> 1 cursor.execute("create table testsql.tablesql(studentid INT(10) , firstname VARCHAR(30) , regid INT(10) , classname VARCHAR(30))")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
# ...

# %%
cursor.execute("use testsql")
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata3',), ('tablesql',)]

# %%
cursor.execute('insert into testsql.tablesql values(13113,"fhhgh",  234,"jhvhjkhg")')

# %%
cursor.fetchall()
# Out:
# []

# %%
shu.commit()
# to show a data values until you commit cant show in sql

# %%
cursor.execute('select * from testsql.tablesql ')

# %%
cursor.fetchall()
# Out:
# [(13113, 'shubham', 4441, 'aaffa'),
#  (13113, 'shubham', 234, 'dharmraj'),
#  (13113, 'fhhgh', 234, 'jhvhjkhg')]

# %%
cursor.execute('create table testsql.glassdata3(col1 INT(10) ,col2 float(10,5),col3 float(10,5) ,col4 float(10,5) , col5 float(10,5),col6 float(10,5) ,clo7 float(10,5) , col8 float(10,5) , col9 float(10,5) , col10 float(10,5) , col11 INT(10)) ')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata3',), ('tablesql',)]

# %%
#cursor.execute('select * form testsql.glassdata3')
#error

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 7293-F0DC
#
#  Directory of C:\Users\shubh\ineuron files
#
# 07-02-2023  11:49 PM    <DIR>          .
# 02-02-2023  01:18 PM    <DIR>          ..
# 07-02-2023  07:19 PM    <DIR>          .ipynb_checkpoints
# 31-10-2021  12:32 PM             6,893 -1.14-windows.xml
# 20-02-2022  06:16 PM         4,407,102 19.3 MongoDB.7z
# 13-03-2022  06:46 PM             9,346 19.3.1 mongoDB introduction.ipynb
# 13-03-2022  09:29 PM           557,521 19.3.2 pyMongo.ipynb
# 09-04-2022  11:24 AM            13,918 9- 4 -22  flask review project.ipynb
# 23-12-2021  09:54 PM           102,264 abcd.ipynb
# 04-02-2022  10:47 PM            28,711 class and object.ipynb
# 18-03-2022  11:11 AM             5,658 cricket.csv
# 16-01-2022  11:46 AM            13,282 Exception handling class 1.ipynb
# 23-01-2022  10:18 AM            62,825 Exception handling class 2.ipynb
# 06-02-2023  08:51 PM         2,546,942 for loops while loop (1).ipynb
# ...

# %%
 file  = open("glass.data", 'r')

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
import csv
with open('glass.data', 'r') as f:
    glass_data =  csv.reader(f , delimiter = '\n')
    for i in glass_data:
        print(i)
        print(f'insert into testsql.glassdata3 values ({str(i[0])})')
        cursor.execute('insert into testsql.glassdata3 values({values})'.format(values = ((i[0]))))
        shu.commit()
#inserting all data into  glass db using loop
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# insert into testsql.glassdata3 values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# insert into testsql.glassdata3 values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# insert into testsql.glassdata3 values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# insert into testsql.glassdata3 values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# insert into testsql.glassdata3 values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# insert into testsql.glassdata3 values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ...

# %%
cursor.execute('insert into testsql.glassdata3 values(48,1.52667,13.99,3.70,0.71,71.57,0.02,9.82,0.00,0.10,1)')

# %%
shu.commit()

# %%
cursor.execute('select * from testsql.glassdata3')

# %%
cursor.fetchall()
# Out:
# [(48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
# ...

# %%
import pandas as pd 
# fetch sql db using panda

# %%
pd.read_sql("select * from testsql.glassdata3 ",shu)
# Out:
#      col1     col2   col3  col4  col5   col6  clo7  col8  col9  col10  col11
# 0      48  1.52667  13.99  3.70  0.71  71.57  0.02  9.82  0.00    0.1      1
# 1      48  1.52667  13.99  3.70  0.71  71.57  0.02  9.82  0.00    0.1      1
# 2       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 3       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 4       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 211   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# 212   211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.0      7
# 213   212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.0      7
# 214   213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.0      7
# 215   214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.0      7
#
# [216 rows x 11 columns]

# %%
pd.read_sql('show databases' , shu)
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3                 sys
# 4            tesstsql
# 5             testsql

# %%
pd.read_sql('show databases' , shu)
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3                 sys
# 4            tesstsql
# 5             testsql

# %%
#######2nd video

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = "localhost", user  =  "root" , passwd = "shubham098")

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases ")
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('tesstsql',),
#  ('tesstsql2',),
#  ('testsql',)]

# %%
cursor.execute("select * from testsql.glassdata3")
cursor.fetchall()
# Out:
# [(48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 2.0, 8.0, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
cursor.execute("select col1 , col5 ,col10 from testsql.glassdata3")

# %%
cursor.fetchall()
# Out:
# [(48, 0.71, 0.1),
#  (48, 0.71, 0.1),
#  (1, 1.1, 0.0),
#  (2, 1.36, 0.0),
#  (3, 1.54, 0.0),
#  (4, 1.29, 0.0),
#  (5, 1.24, 0.0),
#  (6, 1.62, 0.26),
#  (7, 1.14, 0.0),
#  (8, 1.05, 0.0),
#  (9, 1.37, 0.0),
#  (10, 1.36, 0.11),
#  (11, 1.56, 0.24),
#  (12, 1.27, 0.0),
#  (13, 1.4, 0.24),
#  (14, 1.27, 0.17),
#  (15, 1.31, 0.0),
#  (16, 1.23, 0.0),
#  (17, 1.16, 0.0),
#  (18, 0.89, 0.0),
#  (19, 1.18, 0.0),
#  (20, 1.69, 0.07),
#  (21, 1.49, 0.19),
#  (22, 0.29, 0.0),
#  (23, 1.29, 0.0),
#  (24, 1.35, 0.0),
#  (25, 1.15, 0.0),
#  (26, 1.21, 0.0),
#  (27, 1.41, 0.0),
#  (28, 1.33, 0.0),
#  (29, 1.43, 0.0),
#  (30, 1.28, 0.0),
#  (31, 1.3, 0.14),
#  (32, 1.14, 0.0),
#  (33, 1.23, 0.22),
#  (34, 1.38, 0.06),
#  (35, 1.34, 0.0),
#  (36, 1.21, 0.0),
#  (37, 1.32, 0.0),
#  (38, 1.35, 0.0),
#  (39, 0.47, 0.0),
#  (40, 0.47, 0.0),
#  (41, 1.12, 0.0),
#  (42, 1.2, 0.0),
#  (43, 1.33, 0.0),
#  (44, 0.72, 0.0),
#  (45, 1.19, 0.3),
#  (46, 1.35, 0.0),
#  (47, 1.18, 0.16),
#  (48, 0.71, 0.1),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 where col1=5 ")

# %%
cursor.fetchall()
# Out:
# [(5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1)]

# %%
cursor.execute("delete from testsql.glassdata3 where col1 = 4")

# %%
mydb.commit()

# %%
cursor.execute("select * from testsql.glassdata3 where col1=4")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("UPDATE   testsql.glassdata3 SET col2 = 2 , col3 = 8 where col1 = 6  ")

# %%
mydb.commit()

# %%
cursor.execute("select * from testsql.glassdata3")

# %%
cursor.fetchall()
# Out:
# [(48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 2.0, 8.0, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 where col1 = 6")

# %%
cursor.fetchall()
# Out:
# [(6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select  count(col1) , col2  from testsql.glassdata3 group by col1 ")
cursor.fetchall()
# Out:
# [(3, 1.52667),
#  (1, 1.52101),
#  (1, 2.0),
#  (1, 1.51618),
#  (1, 1.51742),
#  (1, 2.0),
#  (1, 1.51743),
#  (1, 1.51756),
#  (1, 1.51918),
#  (1, 1.51755),
#  (1, 1.51571),
#  (1, 1.51763),
#  (1, 1.51589),
#  (1, 1.51748),
#  (1, 1.51763),
#  (1, 1.51761),
#  (1, 1.51784),
#  (1, 1.52196),
#  (1, 1.51911),
#  (1, 1.51735),
#  (1, 1.5175),
#  (1, 1.51966),
#  (1, 1.51736),
#  (1, 1.51751),
#  (1, 1.5172),
#  (1, 1.51764),
#  (1, 1.51793),
#  (1, 1.51721),
#  (1, 1.51768),
#  (1, 1.51784),
#  (1, 1.51768),
#  (1, 1.51747),
#  (1, 1.51775),
#  (1, 1.51753),
#  (1, 1.51783),
#  (1, 1.51567),
#  (1, 1.51909),
#  (1, 1.51797),
#  (1, 1.52213),
#  (1, 1.52213),
#  (1, 1.51793),
#  (1, 1.51755),
#  (1, 1.51779),
#  (1, 1.5221),
#  (1, 1.51786),
#  (1, 1.519),
#  (1, 1.51869),
#  (1, 1.52223),
#  (1, 1.51898),
#  (1, 1.5232),
#  (1, 1.51926),
#  (1, 1.51808),
#  (1, 1.51837),
#  (1, 1.51778),
#  (1, 1.51769),
#  (1, 1.51215),
#  (1, 1.51824),
#  (1, 1.51754),
#  (1, 1.51754),
# ...

# %%
cursor.execute("select col1 , count(col1) , col11 from testsql.glassdata3 group by col1")
cursor.fetchall()
# Out:
# [(48, 3, 1),
#  (1, 1, 1),
#  (2, 1, 1),
#  (3, 1, 1),
#  (5, 1, 1),
#  (6, 1, 1),
#  (7, 1, 1),
#  (8, 1, 1),
#  (9, 1, 1),
#  (10, 1, 1),
#  (11, 1, 1),
#  (12, 1, 1),
#  (13, 1, 1),
#  (14, 1, 1),
#  (15, 1, 1),
#  (16, 1, 1),
#  (17, 1, 1),
#  (18, 1, 1),
#  (19, 1, 1),
#  (20, 1, 1),
#  (21, 1, 1),
#  (22, 1, 1),
#  (23, 1, 1),
#  (24, 1, 1),
#  (25, 1, 1),
#  (26, 1, 1),
#  (27, 1, 1),
#  (28, 1, 1),
#  (29, 1, 1),
#  (30, 1, 1),
#  (31, 1, 1),
#  (32, 1, 1),
#  (33, 1, 1),
#  (34, 1, 1),
#  (35, 1, 1),
#  (36, 1, 1),
#  (37, 1, 1),
#  (38, 1, 1),
#  (39, 1, 1),
#  (40, 1, 1),
#  (41, 1, 1),
#  (42, 1, 1),
#  (43, 1, 1),
#  (44, 1, 1),
#  (45, 1, 1),
#  (46, 1, 1),
#  (47, 1, 1),
#  (49, 1, 1),
#  (50, 1, 1),
#  (51, 1, 1),
#  (52, 1, 1),
#  (53, 1, 1),
#  (54, 1, 1),
#  (55, 1, 1),
#  (56, 1, 1),
#  (57, 1, 1),
#  (58, 1, 1),
#  (59, 1, 1),
#  (60, 1, 1),
#  (61, 1, 1),
#  (62, 1, 1),
#  (63, 1, 1),
#  (64, 1, 1),
#  (65, 1, 1),
#  (66, 1, 1),
#  (67, 1, 1),
#  (68, 1, 1),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 where col1=6")

# %%
cursor.fetchall()
# Out:
# [(6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
mydb.execute("show tables")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9992/2449171281.py in <module>
# ----> 1 mydb.execute("show tables")
#
# AttributeError: 'CMySQLConnection' object has no attribute 'execute'

# %%
cursor.execute("use testsql")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('glassdata3',), ('tablesql',)]

# %%
cursor.execute("select *  from testsql.tablesql  ")
cursor.fetchall()
# Out:
# [(13113, 'shubham', 4441, 'aaffa'),
#  (13113, 'shubham', 234, 'dharmraj'),
#  (13113, 'fhhgh', 234, 'jhvhjkhg')]

# %%
cursor.execute("select *  from testsql.glassdata3  ")
cursor.fetchall()
# Out:
# [(48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 2.0, 8.0, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
cursor.execute("select col1 , col2 , col11 from testsql.glassdata3 where col1 = 11 or col11 = 2")
cursor.fetchall()
# Out:
# [(11, 1.51571, 1),
#  (71, 1.51574, 2),
#  (72, 1.51848, 2),
#  (73, 1.51593, 2),
#  (74, 1.51631, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (77, 1.51645, 2),
#  (78, 1.51627, 2),
#  (79, 1.51613, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (83, 1.51646, 2),
#  (84, 1.51594, 2),
#  (85, 1.51409, 2),
#  (86, 1.51625, 2),
#  (87, 1.51569, 2),
#  (88, 1.51645, 2),
#  (89, 1.51618, 2),
#  (90, 1.5164, 2),
#  (91, 1.51841, 2),
#  (92, 1.51605, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (95, 1.51629, 2),
#  (96, 1.5186, 2),
#  (97, 1.51841, 2),
#  (98, 1.51743, 2),
#  (99, 1.51689, 2),
#  (100, 1.51811, 2),
#  (101, 1.51655, 2),
#  (102, 1.5173, 2),
#  (103, 1.5182, 2),
#  (104, 1.52725, 2),
#  (105, 1.5241, 2),
#  (106, 1.52475, 2),
#  (107, 1.53125, 2),
#  (108, 1.53393, 2),
#  (109, 1.52222, 2),
#  (110, 1.51818, 2),
#  (111, 1.52664, 2),
#  (112, 1.52739, 2),
#  (113, 1.52777, 2),
#  (114, 1.51892, 2),
#  (115, 1.51847, 2),
#  (116, 1.51846, 2),
# ...

# %% [raw]
# cursor.execute(

# %%
cursor.execute("select * from testsql.glassdata3 where col2 like '1.515%' ")
cursor.fetchall()
# fetching row having 1.515... in col 2
# Out:
# [(11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (84, 1.51594, 13.09, 3.52, 1.55, 72.87, 0.68, 8.05, 0.0, 0.09, 2),
#  (87, 1.51569, 13.24, 3.49, 1.47, 73.25, 0.38, 8.03, 0.0, 0.0, 2),
#  (93, 1.51588, 13.12, 3.41, 1.58, 73.26, 0.07, 8.39, 0.0, 0.19, 2),
#  (94, 1.5159, 13.24, 3.34, 1.47, 73.1, 0.39, 8.22, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 where col2 like '%.5%' ")
cursor.fetchall()
# Out:
# [(48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsql.glassdata3")
cursor.fetchall()
# Out:
# [(48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 2.0, 8.0, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 order by col1 ")
# oder by ascending order

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 2.0, 8.0, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 order by col2 desc ")
#decending
cursor.fetchall()
# Out:
# [(2, 2.0, 8.0, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (6, 2.0, 8.0, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2),
#  (104, 1.52725, 13.8, 3.15, 0.66, 70.57, 0.08, 11.64, 0.0, 0.0, 2),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (111, 1.52664, 11.23, 0.0, 0.77, 73.21, 0.0, 14.68, 0.0, 0.0, 2),
#  (132, 1.52614, 13.7, 0.0, 1.36, 71.24, 0.19, 13.44, 0.0, 0.1, 2),
#  (106, 1.52475, 11.45, 0.0, 1.88, 72.19, 0.81, 13.24, 0.0, 0.34, 2),
#  (105, 1.5241, 13.83, 2.9, 1.17, 71.15, 0.08, 10.79, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select * from testsql.glassdata3 where col1 > 100")
cursor.fetchall()
#without or fetch rows above 100 in col1
# Out:
# [(101, 1.51655, 12.75, 2.85, 1.44, 73.27, 0.57, 8.79, 0.11, 0.22, 2),
#  (102, 1.5173, 12.35, 2.72, 1.63, 72.87, 0.7, 9.23, 0.0, 0.0, 2),
#  (103, 1.5182, 12.62, 2.76, 0.83, 73.81, 0.35, 9.42, 0.0, 0.2, 2),
#  (104, 1.52725, 13.8, 3.15, 0.66, 70.57, 0.08, 11.64, 0.0, 0.0, 2),
#  (105, 1.5241, 13.83, 2.9, 1.17, 71.15, 0.08, 10.79, 0.0, 0.0, 2),
#  (106, 1.52475, 11.45, 0.0, 1.88, 72.19, 0.81, 13.24, 0.0, 0.34, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (109, 1.52222, 14.43, 0.0, 1.0, 72.67, 0.1, 11.52, 0.0, 0.08, 2),
#  (110, 1.51818, 13.72, 0.0, 0.56, 74.45, 0.0, 10.99, 0.0, 0.0, 2),
#  (111, 1.52664, 11.23, 0.0, 0.77, 73.21, 0.0, 14.68, 0.0, 0.0, 2),
#  (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (114, 1.51892, 13.46, 3.83, 1.26, 72.55, 0.57, 8.21, 0.0, 0.14, 2),
# ...

# %%
cursor.execute("select * from (select * from testsql.glassdata3 where col1 > 100) as shubh where col11=3")
cursor.fetchall()
#nested
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...
